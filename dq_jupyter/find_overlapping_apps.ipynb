# %%
import pandas as pd
apple = pd.read_csv("AppleStore.csv")
google = pd.read_csv("googleplaystore.csv")

# %%
apple.head(1)
# Out:
#    Unnamed: 0         id       track_name  size_bytes currency  price  \
# 0           1  281656475  PAC-MAN Premium   100788224      USD   3.99
#
#    rating_count_tot  rating_count_ver  user_rating  user_rating_ver    ver  \
# 0             21292                26          4.0              4.5  6.3.5
#
#   cont_rating prime_genre  sup_devices.num  ipadSc_urls.num  lang.num  vpp_lic
# 0          4+       Games               38                5        10        1

# %%
google.head(1)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
#
#   Reviews Size Installs  Type Price Content Rating        Genres  \
# 0     159  19M  10,000+  Free     0       Everyone  Art & Design
#
#       Last Updated Current Ver   Android Ver
# 0  January 7, 2018       1.0.0  4.0.3 and up

# %%
df_apple = pd.DataFrame({"name":apple["track_name"]})
df_apple["name"]=df_apple["name"].str.replace("-"," ")
df_apple["name"]=df_apple["name"].str.replace("&"," ")
df_apple["name"]=df_apple["name"].str.replace(","," ")
df_apple["name"]=df_apple["name"].str.replace(":","")
new = df_apple["name"].str.split(" ",n=3,expand=True)
df_apple["0"] = new[0]
df_apple["1"]=new[1]
df_apple["2"]=new[2]

# %%
df_apple["apple_value"] = 1

# %%
df_apple.head()
# Out:
#                                                 name           0     1  \
# 0                                    PAC MAN Premium         PAC   MAN
# 1                          Evernote   stay organized    Evernote
# 2    WeatherBug   Local Weather  Radar  Maps  Alerts  WeatherBug
# 3  eBay Best App to Buy  Sell  Save! Online Shopping        eBay  Best
# 4                                              Bible       Bible  None
#
#          2  apple_value
# 0  Premium            1
# 1                     1
# 2                     1
# 3      App            1
# 4     None            1

# %%
df_google = pd.DataFrame({"name":google["App"]})
df_google["name"]=df_google["name"].str.replace("-"," ")
df_google["name"]=df_google["name"].str.replace("&"," ")
df_google["name"]=df_google["name"].str.replace(":","")
df_google["name"]=df_google["name"].str.replace(","," ")
new = df_google["name"].str.split(" ",n=3,expand=True)
df_google["0"] = new[0]
df_google["1"] = new[1]
df_google["2"] = new[2]
df_google["google_value"] = 1
df_google.head()
# Out:
#                                                 name         0         1  \
# 0     Photo Editor   Candy Camera   Grid   ScrapBook     Photo    Editor
# 1                                Coloring book moana  Coloring      book
# 2  U Launcher Lite – FREE Live Cool Themes  Hide ...         U  Launcher
# 3                              Sketch   Draw   Paint    Sketch
# 4              Pixel Draw   Number Art Coloring Book     Pixel      Draw
#
#        2  google_value
# 0                    1
# 1  moana             1
# 2   Lite             1
# 3                    1
# 4                    1

# %%
combine = pd.merge(df_apple,df_google,how="outer",on=["0","1","2"])
combine.head()
# Out:
#                                               name_x           0     1  \
# 0                                    PAC MAN Premium         PAC   MAN
# 1                          Evernote   stay organized    Evernote
# 2    WeatherBug   Local Weather  Radar  Maps  Alerts  WeatherBug
# 3  eBay Best App to Buy  Sell  Save! Online Shopping        eBay  Best
# 4                                              Bible       Bible  None
#
#          2  apple_value name_y  google_value
# 0  Premium          1.0    NaN           NaN
# 1                   1.0    NaN           NaN
# 2                   1.0    NaN           NaN
# 3      App          1.0    NaN           NaN
# 4     None          1.0  Bible           1.0

# %%
combine["both"] = combine["apple_value"]+combine["google_value"]
combine = combine[combine["both"]==2]
combine["name_x"].nunique()
# Out:
# 552

# %%
distinct = pd.DataFrame({"name":combine["name"].unique()})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'name'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-52507cf7b428> in <module>
# ...

# %%
distinct.to_csv("overlapping_apps.csv")
